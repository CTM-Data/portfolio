# %%
import pandas as pd

years = list(range(2017, 2024))
min = years[0]
max = years[-1]
df = pd.DataFrame()

# %%
for year in years:
    url = rf'https://www.pro-football-reference.com/years/{year}/fantasy.htm#fantasy'
    df_temp = pd.read_html(url, skiprows=0)[0]
    df_temp.columns = [f'{tup[0]}_{tup[1]}' if 'Unnamed' not in tup[0] else f'{tup[1]}' for tup in df_temp.columns]
    df_temp.Player = df_temp.Player.str.replace('*', '').str.replace('+', '')
    rows_w_headers = list(range(29, df_temp.shape[0], 31))
    df_temp = df_temp.drop(labels=rows_w_headers)
    df_temp = df_temp.fillna(0)
    df_temp['Year'] = year
    df = pd.concat([df, df_temp], ignore_index=True)

# %%
df.head()
# Out:
#   Rk         Player   Tm FantPos Age Games_G Games_GS Passing_Cmp Passing_Att  \
# 0  1    Todd Gurley  LAR      RB  23      15       15           0           0
# 1  2   Le'Veon Bell  PIT      RB  25      15       15           0           0
# 2  3    Kareem Hunt  KAN      RB  22      16       16           0           0
# 3  4   Alvin Kamara  NOR      RB  22      16        3           0           0
# 4  5  Melvin Gordon  LAC      RB  24      16       16           0           0
#
#   Passing_Yds  ... Scoring_2PM Scoring_2PP Fantasy_FantPt Fantasy_PPR  \
# 0           0  ...           0           0            319       383.3
# 1           0  ...           0           0            257       341.6
# 2           0  ...           0           0            242       295.2
# 3           0  ...           1           0            239       320.4
# 4           0  ...           0           0            230       288.1
#
# ...

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Tm', 'FantPos', 'Age', 'Games_G', 'Games_GS',
#        'Passing_Cmp', 'Passing_Att', 'Passing_Yds', 'Passing_TD',
#        'Passing_Int', 'Rushing_Att', 'Rushing_Yds', 'Rushing_Y/A',
#        'Rushing_TD', 'Receiving_Tgt', 'Receiving_Rec', 'Receiving_Yds',
#        'Receiving_Y/R', 'Receiving_TD', 'Fumbles_Fmb', 'Fumbles_FL',
#        'Scoring_TD', 'Scoring_2PM', 'Scoring_2PP', 'Fantasy_FantPt',
#        'Fantasy_PPR', 'Fantasy_DKPt', 'Fantasy_FDPt', 'Fantasy_VBD',
#        'Fantasy_PosRank', 'Fantasy_OvRank', 'Year'],
#       dtype='object')

# %%
# prob_rows = list(range(29, df.shape[0], 31))
# for row in prob_rows:
#     print(df.iloc[row])

# %%
# dtypes = {
#     'Rushing_Att': int,
#     'Receiving_Tgt': int, 
#     'Rushing_Yds': float,
#     'Receiving_Yds': float,
#     'Games_G': int,
#     'Fantasy_PPR': float
# }

# df.astype(dtypes)

# %%
df.dtypes
# Out:
# Rk                 object
# Player             object
# Tm                 object
# FantPos            object
# Age                object
# Games_G            object
# Games_GS           object
# Passing_Cmp        object
# Passing_Att        object
# Passing_Yds        object
# Passing_TD         object
# Passing_Int        object
# Rushing_Att        object
# Rushing_Yds        object
# Rushing_Y/A        object
# Rushing_TD         object
# Receiving_Tgt      object
# Receiving_Rec      object
# Receiving_Yds      object
# Receiving_Y/R      object
# Receiving_TD       object
# Fumbles_Fmb        object
# Fumbles_FL         object
# Scoring_TD         object
# Scoring_2PM        object
# Scoring_2PP        object
# Fantasy_FantPt     object
# Fantasy_PPR        object
# Fantasy_DKPt       object
# Fantasy_FDPt       object
# Fantasy_VBD        object
# Fantasy_PosRank    object
# Fantasy_OvRank     object
# Year                int64
# dtype: object

# %%
df.convert_dtypes()
df.dtypes
# Out:
# Rk                 object
# Player             object
# Tm                 object
# FantPos            object
# Age                object
# Games_G            object
# Games_GS           object
# Passing_Cmp        object
# Passing_Att        object
# Passing_Yds        object
# Passing_TD         object
# Passing_Int        object
# Rushing_Att        object
# Rushing_Yds        object
# Rushing_Y/A        object
# Rushing_TD         object
# Receiving_Tgt      object
# Receiving_Rec      object
# Receiving_Yds      object
# Receiving_Y/R      object
# Receiving_TD       object
# Fumbles_Fmb        object
# Fumbles_FL         object
# Scoring_TD         object
# Scoring_2PM        object
# Scoring_2PP        object
# Fantasy_FantPt     object
# Fantasy_PPR        object
# Fantasy_DKPt       object
# Fantasy_FDPt       object
# Fantasy_VBD        object
# Fantasy_PosRank    object
# Fantasy_OvRank     object
# Year                int64
# dtype: object

# %%
df['Opps/g'] = (df.Rushing_Att + df.Receiving_Tgt) / df.Games_G
df['ScrmYds/g'] = (df.Rushing_Yds + df.Receiving_Yds) / df.Games_G
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Clayton.Marquardt\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File c:\Users\Clayton.Marquardt\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\Clayton.Marquardt\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
# ...

# %%
# df.to_csv(f'../historical_data/ff_historical_{min}_{max}.csv', index=False)
